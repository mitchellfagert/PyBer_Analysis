# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt

# %%
#Set the x-axis to a list of string for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

#Set the y-axis to a list of floats as the total fare i nUS dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.80, 20.71, 20.09]

# %%
#Create the plot
plt.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis,y_axis)

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
# create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')

# create labels for the x and y axes
plt.xlabel("Date")
plt.ylabel("Fare($)")

# Set the y limit between 0 and 45.
plt.ylim(0, 45)

# Create a title
plt.title("PyBer Fare by Month")

# Add the legend.
plt.legend()

# %%
#Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot
plt.bar(x_axis, y_axis, color="green", label='Boston')

#create labels for the x and y axis.
plt.xlabel("Date")
plt.ylabel("Fare($)")

#Create a title.
plt.title("PyBer Fare by Month")

#Add the legend.
plt.legend()

# %%
#Create a horizontal bar chart. Create the plot.
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create a horizontal bar chart but showing data on opposite axis.
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#Create a horizontal bar chart. Create the plot. Skill drill
plt.barh(x_axis, y_axis, color="magenta", label="Boston")
plt.gca().invert_yaxis()

#Add a title and axes labels
plt.xlabel("Fare($)")
plt.ylabel("Date")
plt.title("PyBer Fare by Month")
# Out:
# Text(0.5, 1.0, 'PyBer Fare by Month')

# %%
# Create a bar chart using the Object-Oriented Method
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
#Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create horizontal bar chart with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# SKILL DRILL Create horizontal bar chart with ax.plt()
fig, ax = plt.subplots()
#Change color to cyan and add legend for city of Chicago
ax.barh(x_axis, y_axis, color="cyan")
ax.set_title("PyBer Fare by Month")
ax.legend("Chicago")
#Add a title and axes labels
ax.set_xlabel("Fare($)")
ax.set_ylabel("Date")
#Invert the y-axis data
ax.invert_yaxis()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis, y_axis, 'o')

# %%
#skill drill
#Change the color of the markers to red
plt.scatter(y_axis, x_axis, c='red', label = "Chicago")
plt.gca().invert_yaxis()
plt.xlim(0,50)
plt.title('Pyber Fare by Month')
plt.ylabel('Date')
plt.xlabel('Fare($)')
plt.legend()
#Add a legend for the city of Chicago
#Swith the axis so the the Fare($) data is on the x-axis
#Add a limit for the x-axis data

#invert the y-Axis so that January is at the top

# %%
#Create a bubble plot
plt.scatter(x_axis, y_axis, s=y_axis_larger)
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11380\4214369043.py in <module>
#       1 #Create a bubble plot
# ----> 2 plt.scatter(x_axis, y_axis, s=y_axis_larger)
#       3 y_axis_larger = []
#       4 for data in y_axis:
#       5     y_axis_larger.append(data*3)
#
# NameError: name 'y_axis_larger' is not defined

# %%
#refactor code using list comprehension
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
#Create scatter Plot using the Object Oriented Interface
fig, ax = plt.subplots()
ax.scatter(x_axis,y_axis)

# %%
#Create bubble chart using the Object-Oriented Interface
fig, ax = plt.subplots()
ax.scatter(x_axis,y_axis, s=y_axis)

# %%
#SkillDrill
fig, ax = plt.subplots()
ax.scatter(y_axis,
           x_axis,
           fc='#75bbfd', 
           alpha= 0.2, 
           edgecolor="black", 
           linewidth=2, 
           s = [i * 5 for i in y_axis], 
           label="Boston")
plt.gca().invert_yaxis()
plt.xlim(0, 50)
plt.title("PyBer Fare by Month")
plt.xlabel("Fare ($)")
plt.ylabel("Date")
plt.legend()

# %%
#Create a pie chart using Matlab Method
plt.pie(y_axis, labels=x_axis)
# Out:
# ([<matplotlib.patches.Wedge at 0x1abd2c48508>,
#   <matplotlib.patches.Wedge at 0x1abd2c48ec8>,
#   <matplotlib.patches.Wedge at 0x1abd2c524c8>,
#   <matplotlib.patches.Wedge at 0x1abd2c52bc8>,
#   <matplotlib.patches.Wedge at 0x1abd2c5c308>,
#   <matplotlib.patches.Wedge at 0x1abd2c5ca08>,
#   <matplotlib.patches.Wedge at 0x1abd2c67108>,
#   <matplotlib.patches.Wedge at 0x1abd2c677c8>,
#   <matplotlib.patches.Wedge at 0x1abd2c5c2c8>,
#   <matplotlib.patches.Wedge at 0x1abd2c5c9c8>,
#   <matplotlib.patches.Wedge at 0x1abd2c3f808>,
#   <matplotlib.patches.Wedge at 0x1abd2c7c248>],
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.4998632656180861, 0.9798656620606842, 'Mar'),
#   Text(-0.3293082697128627, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452758, 'June'),
#   Text(-0.7729302540020312, -0.782674148319948, 'July'),
#   Text(-0.2333875250754619, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.4609812999807629, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')])

# %%
#explode example
explode_values = (0,0,0,0,0,0,0.2,0,0,0,0,0)
plt.pie(y_axis, explode = explode_values, labels=x_axis, autopct='%.1f%%')
plt.subplots(figsize=(8,8))
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0,0,0,0,0,0,0.2,0,0,0,0,0)
plt.subplots(figsize=(8,8))
plt.pie(y_axis,
       explode=explode_values,
       colors=colors,
       labels=x_axis,
       autopct='%.1f%%')

plt.show()

# %%
#Create a pie chart using Object Oriented Interface
